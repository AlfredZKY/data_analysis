# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号

# %%
print(sys.version)
# Out:
# 3.5.4 |Anaconda custom (64-bit)| (default, Aug 14 2017, 13:26:58)
# [GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]

# %% [markdown]
# # 1.数据可视化的目的
# # * 探索数据
# # * 沟通
# # Figure->Axes->(Line2D,Text,etc) 一份Figure对象可以包含多个子图(Axes),在matplotlib中用Axes对象表示绘制区域，可以理解为子图。

# %% [markdown]
# # 2 pyplot初步

# %%
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

plt.plot(years, gdp, color='red', marker='o', linestyle='solid')
plt.title('Nominal GDP')
plt.ylabel('Billions of $')
plt.xlabel('Years')

# %%
movies = ["Annie Hall", "Ben-Hur", "Casablanca", "Gandhi", "West Side Story"]
num_oscars = [5, 11, 3, 8, 10]
res = [i for i ,_ in enumerate(movies)]
print(res)
xs = [i+0.1 for i ,_ in enumerate(movies)]
print(xs)
plt.bar(xs,num_oscars)

plt.title('My Favorite Movies')
plt.ylabel('# of Academy Awards')
plt.xticks([i+0.5 for i ,_ in enumerate(movies)])
# Out:
# [0, 1, 2, 3, 4]
# [0.1, 1.1, 2.1, 3.1, 4.1]
# ([<matplotlib.axis.XTick at 0x7fd8c7cc4710>,
#   <matplotlib.axis.XTick at 0x7fd8c7cc4be0>,
#   <matplotlib.axis.XTick at 0x7fd8c7cc1550>,
#   <matplotlib.axis.XTick at 0x7fd8c4fbceb8>,
#   <matplotlib.axis.XTick at 0x7fd8c4fc4908>],
#  <a list of 5 Text xticklabel objects>)

# %% [markdown]
# $ y = a + bx $
# $$legend的说明$$

# %%
variance = [1, 2, 4, 8, 16, 32, 64, 128, 256]
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1]
total_error = [x + y for x, y in zip(variance, bias_squared)]
xs = [i for i, _ in enumerate(variance)]

# green solid line
plt.plot(xs, variance, 'g-', label='variance')

# red dot-dashed line
plt.plot(xs, bias_squared, 'r-.', label='bias^2')

# blue dotted line
plt.plot(xs, total_error, 'b:', label='total error')

# loc= 9 means "top center"
# 显示出线的label
plt.legend(loc=9)

plt.xlabel("model complexity")
plt.title("The Bias-Variance Tradeoff")

# %% [markdown]
# # 3.scatter 散点图

# %%
friends = [70, 65, 72, 63, 71, 64, 60, 64, 67]
minutes = [175, 170, 205, 120, 220, 130, 105, 145, 190]
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']
plt.scatter(friends, minutes)

# label each point
for label,friend_count,minute_count in zip(labels,friends,minutes):
    # annotate 注释加说明
    plt.annotate(label,
                xy=(friend_count,minute_count),# put the label with its point
                xytext=(5,-5),                 # but slightly offset
                textcoords = "offset points")

plt.title("Daily Minutes vs. Number of Friends")
plt.xlabel("# of friends")
plt.ylabel("daily minutes spent on the site")

# %% [markdown]
# # 3.matplotlib 各种绘图参数
# https://github.com/rougier/matplotlib-tutorial

# %%
X = np.linspace(-np.pi,np.pi,256,endpoint=True)
X
# np.linspace?
plt.xlim?

# %%
X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)

# 相当于程序的画布
plt.figure(figsize=(8, 6), dpi=80)

# color，linewidth(pixels)，linestyle
plt.plot(X, C, color="blue", linewidth=3.0, linestyle="--")
plt.plot(X, S, color="green", linewidth=6.0, linestyle="-")

# x limits
plt.xlim(-4, 4.0)

# y limits
plt.ylim(-1.0, 1.0)

# x ticks
plt.xticks(np.linspace(-4, 4, 9, endpoint=True))

# y ticks
plt.yticks(np.linspace(-1.0, 1.0, 5, endpoint=True))
# Out:
# ([<matplotlib.axis.YTick at 0x7efe741bedd8>,
#   <matplotlib.axis.YTick at 0x7efe74531a90>,
#   <matplotlib.axis.YTick at 0x7efe741b9eb8>,
#   <matplotlib.axis.YTick at 0x7efe74296e80>,
#   <matplotlib.axis.YTick at 0x7efe741dd898>],
#  <a list of 5 Text yticklabel objects>)

# %% [markdown]
# # 3.1 绘制cos和sin曲线

# %%
plt.figure(figsize=(8, 5), dpi=80)
plt.subplot(111)

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)

plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-")
plt.plot(X, S, color="red", linewidth=2.5, linestyle="-")

plt.xlim(X.min() * 1.1, X.max() * 1.1)
plt.ylim(C.min() * 1.1, C.max() * 1.1)

plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi], [
    r'$-\pi$',
    r'$-\pi/2$',
    r'$0$',
    r'$+\pi/2$',
    r'$+\pi$',
    
])

plt.yicks([-1, 0, 1], [r'$-1$', r'$0$', r'$+1$'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-48cf494c5e19> in <module>()
#      14          [r'$-\pi$',r'$-\pi/2$',r'$0$',r'$+\pi/2$',r'$+\pi$',])
#      15
# ---> 16 plt.yicks([-1,0,1],
#      17          [r'$-1$',r'$0$',r'$+1$'])
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'yicks'

# %% [markdown]
# # 3.2 移动坐标轴

# %%
plt.figure(figsize=(8, 5), dpi=80)
ax = plt.subplot(111)

# 把坐标轴的右边和上边消除
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# 移动坐标轴成十字,以0,0作为中心坐标
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data', 0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data', 0))

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)

plt.plot(X, C, color='blue', linewidth=2.5, linestyle='-')
plt.plot(X, S, color='red', linewidth=2.5, linestyle='-')

plt.xlim(X.min() * 1.1, X.max() * 1.1)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi],
           [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

plt.ylim(C.min()*1.1,C.max()*1.1)
plt.yticks([-1,0,1],[r'$-1$',r'$0$',r'$+1$'])
# Out:
# ([<matplotlib.axis.YTick at 0x7efe8c2d3f98>,
#   <matplotlib.axis.YTick at 0x7efe8c2c2f28>,
#   <matplotlib.axis.YTick at 0x7efe8c319160>],
#  <a list of 3 Text yticklabel objects>)

# %% [markdown]
# # 3.3 加label

# %%
plt.figure(figsize=(8, 5), dpi=80)
ax = plt.subplot(111)

# 取消右边和上边的坐标轴
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# 移动坐标轴到(0,0)
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data', 0))

ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data', 0))

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)

# 绘图
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-", label="cosine")
plt.plot(X, S, color="red", linewidth=2.5, linestyle="-", label="sine")

# 设置刻度
plt.xlim(X.min() * 1.1, X.max() * 1.1)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi],
           [r'$-\pi/$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

plt.ylim(C.min() * 1.1, C.max() * 1.1)
plt.yticks([-1, 1], [r'$-1$', r'+1'])

# 显示legend
plt.legend(loc='upper left', frameon=False)

# %% [markdown]
# # 3.3 加注释

# %%
plt.figure(figsize=(8, 5), dpi=80)
ax = plt.subplot(111)

# 删除右边和上部的坐标框架
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# 移动坐标轴到(0,0)
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data', 0))

ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data', 0))

# 构造数据
X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)

# 绘制图
plt.plot(X, C, color="blue", linewidth=2.5, linestyle='-', label="cosine")
plt.plot(X, S, color="red", linewidth=2.5, linestyle='-', label="sine")

# 加刻度，并显示
plt.xlim(X.min() * 1.1, X.max() * 1.1)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi, np.pi / 2],
           [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi$', r'$+\pi/2$'])

plt.ylim(C.min() * 1.1, C.max() * 1.1)
plt.yticks([-1, +1], [r'$-1$', r'$+1$'])

# 加legend
plt.legend(loc="upper left", frameon=False)

# 加注释
t = 2 * np.pi / 3

# 加虚线划出某一个点的坐标
plt.plot([t, t], [0, np.cos(t)], color='blue', linewidth=1.5, linestyle='--')

# 画出某一个点坐标，用散点图
plt.scatter([
    t,
], [
    np.cos(t),
], 50, color='blue')

#加注释说明
plt.annotate(r'$\cos(\frac{2\pi}{3})=-\frac{1}{2}$',
             xy=(t, np.cos(t)),
             xycoords='data',
             xytext=(+10, +30),
             textcoords='offset points',
             fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

plt.plot([t,t],[0,np.sin(t)],color="red",linewidth=1.5,linestyle="--")
plt.scatter([t,],[np.sin(t)],50,color='red')
plt.annotate(r'$\sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$',
             xy=(t, np.sin(t)),
             xycoords='data',
             xytext=(+10, +30),
             textcoords='offset points',
             fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

# 字体被线遮挡，设置透明度
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontsize(16)
    label.set_bbox(dict(facecolor='white',edgecolor='None',alpha=0.75))

# %%
plt.annotate?

# %% [markdown]
# # 4 柱状图

# %%
n = 12
X = np.arange(n)
Y1 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)
Y2 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)

plt.bar(X,+Y1,facecolor='#9999ff',edgecolor='white')
plt.bar(X,-Y2,facecolor='#ff9999',edgecolor='white')

for x,y in zip(X,Y1):
    plt.text(x+0.4,y+0.05,'%.2f' % y,ha='center',va='bottom')

plt.ylim(-1.25,1.25)
# Out:
# (-1.25, 1.25)

# %% [markdown]
# # 5.同心扇形

# %%
# polar极坐标
ax = plt.axes([0,0,1,1],polar=True)

N =20
theta = np.arange(0.0,2*np.pi,2*np.pi/N)

radii = 10*np.random.rand(N)
width = np.pi/4*np.random.rand(N)
bars = plt.bar(theta,radii,width=width,bottom=0.0)

for r,bar in zip(radii,bars):
    bar.set_facecolor(plt.cm.jet(r/10.))
    bar.set_alpha(0.5)

ax.set_xticklabels([])
ax.set_yticklabels([])
# Out:
# []

# %%
plt.axes?

# %% [markdown]
# # 6.subplot

# %%
x = [1,2]
y = [2,4]
plt.subplot(2,2,1)
plt.plot(x,y)
plt.subplot(2,2,3)
plt.plot(x,y,color='red')
plt.subplot(2,2,4)

# %%
# 设置画布的大小
fig = plt.figure()
fig.subplots_adjust(bottom=0.025,left=0.025,top=0.975,right=0.975)

plt.subplot(2,1,1)
plt.xticks([])
plt.yticks([])

# plt.subplot(2,3,4)
# plt.subplot(2,3,5)
# plt.subplot(2,3,6)
plt.subplot(2,4,5)
plt.subplot(2,4,6)
plt.subplot(2,4,7)

# %% [markdown]
# # 7.style

# %%
plt.style.use('ggplot')
variance = [1, 2, 4, 8, 16, 32, 64, 128, 256]
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1]
total_error = [x+y for x,y in zip(variance,bias_squared)]
xs = [i for i,_ in enumerate(variance)]

plt.plot(xs,variance,'g-',label='variance')
plt.plot(xs,bias_squared,'r-.',label='bias^2')
plt.plot(xs,total_error,'b:',label='total error')

plt.legend(loc = 9)
plt.xlabel('mode complexity')
plt.title("The Bias-Variance Tradeoff")

# %%
with plt.xkcd():
    variance = [1, 2, 4, 8, 16, 32, 64, 128, 256]
    bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1]
    total_error = [x+y for x,y in zip(variance,bias_squared)]
    xs = [i for i,_ in enumerate(variance)]

    plt.plot(xs,variance,'g-',label='variance')
    plt.plot(xs,bias_squared,'r-.',label='bias^2')
    plt.plot(xs,total_error,'b:',label='total error')

    plt.legend(loc = 9)
    plt.xlabel('mode complexity')
    plt.title("The Bias-Variance Tradeoff")
# Out:
# /root/anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:1288: UserWarning: findfont: Font family ['Humor Sans', 'Comic Sans MS'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.xkcd?

# %% [markdown]
# # 8.中文显示

# %%
def set_ch():
    from pylab import mpl
    mpl.rcParams['font.sans-serif'] = ['simhei'] # 指定默认字体
    mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示方块的问题
